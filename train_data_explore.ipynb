# %%
from data_preprocessing import create_df_tensors

# %% [markdown]
# # Exploration part

# %%
import pandas as pd

df = pd.read_csv("data/train_data.csv")

df.head()
# Out:
#   OPERATIONAL_DAY  TRAIN_NUMBER  OPERATION_TRAIN_NUMBER  \
# 0      2025-01-01             4                     NaN
# 1      2025-01-01             4                     4.0
# 2      2025-01-01             4                     NaN
# 3      2025-01-01             4                     4.0
# 4      2025-01-01             4                     NaN
#
#   OPERATION_TRAFFIC_CATEGORY_ABBREVIATION COMMERCIAL_LINE_NUMBER_DESIGNATION  \
# 0                                     NaN                                NaN
# 1                                      FV                                NaN
# 2                                     NaN                                NaN
# 3                                      FV                                NaN
# 4                                     NaN                                NaN
#
#   TRAIN_GROUP_TRAIN_CATEGORY_ABBREVIATION TRAIN_GROUP_ROUTE  \
# 0                                     ICE   ZUE-BS-BAD-BEOS
# ...

# %%
small_df = df[:100]
small_df.head()
small_df.to_csv("data/train_data_small.csv")

small_df["OPERATING_POINT_ABBREVIATION"].unique()
# Out:
# array(['LSN', 'LANG', 'HBTS', 'EINF', 'SCHL', 'WOES', 'LB', 'MUOS',
#        'GLZB', 'RU', 'GKD', 'ROHS', 'GEXI', 'SIS', 'MU', 'SCOE', 'GMT',
#        'TK', 'AA', 'MELH', 'BSJS', 'LST', 'OLTU', 'DKW', 'BAD', 'LSSS',
#        'BSVB', 'OLO', 'ZLST', 'BS', 'OTH', 'ZUE', 'SCOO', 'DU', 'MAEG',
#        'BSNO', 'DK', 'DT', 'KLW', 'OLN', 'HBTN', 'SILB', 'ZAS', 'AAGB',
#        'LSTN', 'GELN', 'IT', 'OLVL', 'AAO', 'GELL', 'ZHDB'], dtype=object)

# %% [markdown]
# # Create a map with all the stations

# %%
import pandas as pd


# Load  data
stations = pd.read_csv('data/train_stations.csv', delimiter=";", header=0)
train_data = pd.read_parquet("data/train_data.parquet", columns=["OPERATING_POINT_ABBREVIATION"])

merged_df = stations.merge(train_data, on="OPERATING_POINT_ABBREVIATION")

merged_df = merged_df[["OPERATING_POINT_ABBREVIATION","BP_Name", "Latitude","Longitude"]].drop_duplicates(subset=["OPERATING_POINT_ABBREVIATION"])

import plotly.express as px

# Assuming 'stations' DataFrame has columns: 'latitude', 'longitude', and 'station_id'
fig = px.scatter_mapbox(
    merged_df,
    lat='Latitude',
    lon='Longitude',
    hover_name='BP_Name',  # or another identifier column
    zoom=10,
    height=600
)
fig.update_layout(
    mapbox_style="open-street-map",
    margin={"r":0,"t":0,"l":0,"b":0}
)
fig.show()

# %%
merged_df.head()
# Out:
#   OPERATING_POINT_ABBREVIATION            BP_Name   Latitude  Longitude
# 0                           AA             Aarau   47.391354   8.051268
# 2                         AAGB          Aarau GB   47.394524   8.066432
# 4                          AAO  Aarau Ost (Abzw)   47.395252   8.072316
# 6                          BAD      Basel Bad Bf   47.567301   7.606926
# 7                           BS         Basel SBB   47.547406   7.589569

# %% [markdown]
# # Explore final merged dataset with only relevant stations

# %%
import pandas as pd

df = pd.read_parquet("data/train_data_weather.parquet")

#df = df.drop(["OPERATION_TRAFFIC_CATEGORY_ABBREVIATION", "COMMERCIAL_LINE_NUMBER_DESIGNATION", "TRAIN_GROUP_TRAIN_CATEGORY_ABBREVIATION"], axis="columns")
print(df.shape[0])
print(df["PLAN_STOP_TYPE"].value_counts())
df
# Out:
# 278098
# PLAN_STOP_TYPE
# commercialStop     171291
# pass               106789
# operationalStop        18
# Name: count, dtype: int64
#        OPERATIONAL_DAY  TRAIN_NUMBER  OPERATION_TRAIN_NUMBER  \
# 0           2025-01-01          1507                  1507.0
# 1           2025-01-01         15318                 15318.0
# 2           2025-01-01           504                   504.0
# 3           2025-01-01           504                   504.0
# 4           2025-01-01           504                   504.0
# ...                ...           ...                     ...
# 141316      2025-03-31          1547                  1547.0
# 141317      2025-03-31          1547                  1547.0
# 141318      2025-03-31          1547                  1547.0
# 141319      2025-03-31          1547                  1547.0
# 141320      2025-03-31          1547                  1547.0
#
#        OPERATION_TRAFFIC_CATEGORY_ABBREVIATION  \
# 0                                           FV
# ...

# %%
import matplotlib.pyplot as plt

df_temp = df[df["DAILY_PLAN_OPERATIONAL_DELAY_SEC"] > 500]
plt.hist(df_temp["DAILY_PLAN_OPERATIONAL_DELAY_SEC"], bins=10)
# Out:
# (array([676., 267.,  57.,  13.,  31.,  17.,   0.,   1.,  18.,   3.]),
#  array([ 501. ,  866.7, 1232.4, 1598.1, 1963.8, 2329.5, 2695.2, 3060.9,
#         3426.6, 3792.3, 4158. ]),
#  <BarContainer object of 10 artists>)

# %%
df["DAILY_PLAN_OPERATIONAL_DELAY_SEC"].describe()
# Out:
# count    278098.000000
# mean         15.794396
# std          91.829637
# min        -501.000000
# 25%         -20.000000
# 50%           1.000000
# 75%          29.000000
# max        4158.000000
# Name: DAILY_PLAN_OPERATIONAL_DELAY_SEC, dtype: float64
